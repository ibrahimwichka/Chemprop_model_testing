# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
from sklearn.model_selection import KFold
import numpy as np
import os
import subprocess
from chemprop.train import run_training
from chemprop.data import get_data
from chemprop.args import TrainArgs, PredictArgs

def save_temp_data(data, file_path, target_column):
    # Ensure SMILES strings are correctly formatted
    df = pd.DataFrame([(d.smiles[0].strip('[]').strip("'"), d.targets[0]) for d in data], columns=['smiles', target_column+"2"])
    df.to_csv(file_path, index=False)

def debug_csv(file_path):
    # Print out the contents of the CSV file for debugging
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        print(f"Contents of {file_path}:")
        print(df.head())
        print(f"Number of rows: {len(df)}")
    else:
        print(f"File {file_path} does not exist.")

def train_chemprop(train_data_path, save_dir, target_column, num_folds=5, num_trials=3):
    metrics = {'auc': [], 'f1': [], 'accuracy': []}

    for trial in range(num_trials):
        print(f"Starting trial {trial+1}/{num_trials}...")
        
        # Load the dataset
        data = get_data(path=train_data_path, skip_none_targets=True)

        # Extract features and targets
        targets = np.array([d.targets for d in data]).flatten()
        features = [d.smiles for d in data]

        kf = KFold(n_splits=num_folds, shuffle=True, random_state=trial)

        fold_metrics = {'auc': [], 'f1': [], 'accuracy': []}

        for fold, (train_idx, val_idx) in enumerate(kf.split(features)):
            print(f"  Starting fold {fold+1}/{num_folds}...")

            # Split data into training and validation sets
            train_data = [data[i] for i in train_idx]
            val_data = [data[i] for i in val_idx]

            # Save temporary train and validation data
            temp_train_path = f'temp_train_trial_{trial}_fold_{fold}.csv'
            temp_val_path = f'temp_val_trial_{trial}_fold_{fold}.csv'

            save_temp_data(train_data, temp_train_path, target_column)
            save_temp_data(val_data, temp_val_path, target_column)

            # Debug CSV files
            debug_csv(temp_train_path)
            debug_csv(temp_val_path)

            # Define the command to run training
            command = [
                'chemprop_train',
                '--data_path', temp_train_path,
                '--dataset_type', 'classification',
                '--save_dir', os.path.join(save_dir, f'trial_{trial}_fold_{fold}'),
                '--target_columns', target_column,
                '--epochs', '30',
                '--batch_size', '50',
            ]

            try:
                # Run the training command
                subprocess.run(command, check=True)

                # Define the command to run prediction
                predict_command = [
                    'chemprop_predict',
                    '--test_path', temp_val_path,
                    '--checkpoint_dir', os.path.join(save_dir, f'trial_{trial}_fold_{fold}'),
                    '--preds_path', f'preds_trial_{trial}_fold_{fold}.csv'
                ]

                # Run the prediction command
                subprocess.run(predict_command, check=True)

                # Debug prediction file
                debug_csv(f'preds_trial_{trial}_fold_{fold}.csv')

                # Calculate metrics
                preds_df = pd.read_csv(f'preds_trial_{trial}_fold_{fold}.csv')
                # Check the column names and choose the correct one for predictions
                print(f"Prediction file columns: {preds_df.columns}")

                # Replace 'preds' with the actual column name for predictions
                pred_column_name = 'preds'  # Change if necessary based on actual column name
                if pred_column_name not in preds_df.columns:
                    raise KeyError(f"Column '{pred_column_name}' not found in predictions file.")

                # Convert predictions to float
                preds = preds_df[pred_column_name].astype(float)
                true_labels = [d.targets[0] for d in val_data]
                
                # Binarize predictions
                threshold = 0.5
                binary_preds = [1 if x > threshold else 0 for x in preds]

                auc = roc_auc_score(true_labels, preds)
                f1 = f1_score(true_labels, binary_preds)
                accuracy = accuracy_score(true_labels, binary_preds)
                
                fold_metrics['auc'].append(auc)
                fold_metrics['f1'].append(f1)
                fold_metrics['accuracy'].append(accuracy)

            except subprocess.CalledProcessError as e:
                print(f"Error during training or prediction for trial {trial} fold {fold}: {e}")
                continue
            except KeyError as e:
                print(f"KeyError: {e}")
                continue
            except TypeError as e:
                print(f"TypeError: {e}")
                continue

            # Clean up temporary files
            os.remove(temp_train_path)
            os.remove(temp_val_path)
            os.remove(f'preds_trial_{trial}_fold_{fold}.csv')

        # Record the average metrics for this trial
        metrics['auc'].append(np.mean(fold_metrics['auc']))
        metrics['f1'].append(np.mean(fold_metrics['f1']))
        metrics['accuracy'].append(np.mean(fold_metrics['accuracy']))

    # Calculate the average of each metric over all trials
    avg_metrics = {key: np.mean(values) for key, values in metrics.items()}

    return avg_metrics

def main():
    data_path = 'data/TG2_cleaned_smiles_activity.csv'  # Update this with your data path
    save_dir = 'acheckp'  # Update this with your checkpoint directory
    target_column = 'Activity'  # Update this with your target column name

    metrics = train_chemprop(data_path, save_dir, target_column)

    print('Average metrics over 50 trials of 5-fold cross-validation:')
    print(f"AUC: {metrics['auc']}")
    print(f"F1 Score: {metrics['f1']}")
    print(f"Accuracy: {metrics['accuracy']}")

if __name__ == "__main__":
    main()
# Out:
# Starting trial 1/3...
# 336it [00:00, 153986.69it/s]
# 100%|██████████| 336/336 [00:00<00:00, 255722.40it/s]
# 100%|██████████| 336/336 [00:00<00:00, 6454.70it/s]
#   Starting fold 1/5...
# Contents of temp_train_trial_0_fold_0.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 3  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 4  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# Number of rows: 268
# Contents of temp_val_trial_0_fold_0.csv:
#                                               smiles  Activity2
# 0                  NC(=O)C1OC1C(=O)Nc1ccc(Br)c(Cl)c1        1.0
# 1         C=c1[nH]c2ccc(I)cc2c1=Cc1cc(Br)c(O)c(Br)c1        1.0
# 2  O=C(CCOc1ccccc1)N1CCN(C(=O)n2sc3c(ccc[n+]3[O-]...        1.0
# 3  COC(=O)C=CCCC(NC(=O)c1ccc([N+](=O)[O-])cc1C(=O...        1.0
# 4  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# Number of rows: 68
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_0_fold_0.csv --dataset_type classification --save_dir acheckp/trial_0_fold_0 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_0_fold_0.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_0_fold_0',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 0 fold 0: Command '['chemprop_train', '--data_path', 'temp_train_trial_0_fold_0.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_0_fold_0', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 2/5...
# Contents of temp_train_trial_0_fold_1.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 2  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 3  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# 4                  NC(=O)C1OC1C(=O)Nc1ccc(Br)c(Cl)c1        1.0
# Number of rows: 269
# Contents of temp_val_trial_0_fold_1.csv:
#                                               smiles  Activity2
# 0  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 1  O=C(CCl)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# 3  COC(=O)C=CCCC(NC(=O)c1c[nH]c(=O)c([N+](=O)[O-]...        1.0
# 4  C=CC(=O)Nc1ccc(S(=O)(=O)N2CCN(C(=O)N3CCC4CCCCC...        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_0_fold_1.csv --dataset_type classification --save_dir acheckp/trial_0_fold_1 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_0_fold_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_0_fold_1',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 0 fold 1: Command '['chemprop_train', '--data_path', 'temp_train_trial_0_fold_1.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_0_fold_1', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 3/5...
# Contents of temp_train_trial_0_fold_2.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 3  O=C(CCl)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 4                  NC(=O)C1OC1C(=O)Nc1ccc(Br)c(Cl)c1        1.0
# Number of rows: 269
# Contents of temp_val_trial_0_fold_2.csv:
#                                               smiles  Activity2
# 0  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 1  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# 2  C=CC(=O)Nc1ccc(S(=O)(=O)N2CCN(C(=O)C34CC5CC(CC...        1.0
# 3  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# 4  C=C1CC(C(=O)NC(C(=O)NC(C(N)=O)C2CCCCC2)C2CCCCC...        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_0_fold_2.csv --dataset_type classification --save_dir acheckp/trial_0_fold_2 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_0_fold_2.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_0_fold_2',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 0 fold 2: Command '['chemprop_train', '--data_path', 'temp_train_trial_0_fold_2.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_0_fold_2', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 4/5...
# Contents of temp_train_trial_0_fold_3.csv:
#                                               smiles  Activity2
# 0  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 1  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 2  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# 3  O=C(CCl)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 4                  NC(=O)C1OC1C(=O)Nc1ccc(Br)c(Cl)c1        1.0
# Number of rows: 269
# Contents of temp_val_trial_0_fold_3.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 2  C=CC(=O)NCCCCC(NC(=O)Cc1ccccc1)C(=O)N1CCN(c2cc...        1.0
# 3  C=CC(=O)Nc1ncc(S(=O)(=O)N2CCN(C(=O)C34CC5CC(CC...        1.0
# 4  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CBr)C...        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_0_fold_3.csv --dataset_type classification --save_dir acheckp/trial_0_fold_3 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_0_fold_3.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_0_fold_3',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 0 fold 3: Command '['chemprop_train', '--data_path', 'temp_train_trial_0_fold_3.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_0_fold_3', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 5/5...
# Contents of temp_train_trial_0_fold_4.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 3  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 4  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# Number of rows: 269
# Contents of temp_val_trial_0_fold_4.csv:
#                                               smiles  Activity2
# 0  COC(=O)C=CCCC(NC(=O)c1cc(C(=O)O)cc([N+](=O)[O-...        1.0
# 1  COC(=O)C=CCCC(NC(=O)c1ccncc1C(=O)O)C(=O)NC(C(=...        1.0
# 2    C=CC(=O)Nc1ccc(S(=O)(=O)N2CCN(c3ncccc3C)CC2)cc1        1.0
# 3  COC(=O)C=CCCC(NC(=O)c1cncc(C(=O)O)c1)C(=O)NC(C...        1.0
# 4     O=C(CBr)NCC(=O)N1CCN(C(=O)OCc2ccc3ccccc3c2)CC1        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_0_fold_4.csv --dataset_type classification --save_dir acheckp/trial_0_fold_4 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_0_fold_4.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_0_fold_4',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Error during training or prediction for trial 0 fold 4: Command '['chemprop_train', '--data_path', 'temp_train_trial_0_fold_4.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_0_fold_4', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
# Starting trial 2/3...
# 336it [00:00, 283501.54it/s]
# 100%|██████████| 336/336 [00:00<00:00, 268999.07it/s]
# 100%|██████████| 336/336 [00:00<00:00, 170121.46it/s]
#   Starting fold 1/5...
# Contents of temp_train_trial_1_fold_0.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 3  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 4  O=C(CCl)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# Number of rows: 268
# Contents of temp_val_trial_1_fold_0.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# 1                  NC(=O)C1OC1C(=O)Nc1ccc(Br)c(Cl)c1        1.0
# 2  C=CC(=O)Nc1ncc(S(=O)(=O)N2CCN(C(=O)C34CC5CC(CC...        1.0
# 3  O=C(CCOc1ccccc1)N1CCN(C(=O)n2sc3c(ccc[n+]3[O-]...        1.0
# 4  C=C1CC(C(=O)NC(C(=O)NC(C(N)=O)C2CCCCC2)C2CCCCC...        1.0
# Number of rows: 68
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_1_fold_0.csv --dataset_type classification --save_dir acheckp/trial_1_fold_0 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_1_fold_0.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_1_fold_0',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 1 fold 0: Command '['chemprop_train', '--data_path', 'temp_train_trial_1_fold_0.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_1_fold_0', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 2/5...
# Contents of temp_train_trial_1_fold_1.csv:
#                                               smiles  Activity2
# 0  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 1  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 2  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 3  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# 4                  NC(=O)C1OC1C(=O)Nc1ccc(Br)c(Cl)c1        1.0
# Number of rows: 269
# Contents of temp_val_trial_1_fold_1.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  O=C(CCl)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  COC(=O)C=CCCC(NC(=O)c1cc(C(=O)O)cc([N+](=O)[O-...        1.0
# 3  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CBr)C...        1.0
# 4  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_1_fold_1.csv --dataset_type classification --save_dir acheckp/trial_1_fold_1 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_1_fold_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_1_fold_1',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 1 fold 1: Command '['chemprop_train', '--data_path', 'temp_train_trial_1_fold_1.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_1_fold_1', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 3/5...
# Contents of temp_train_trial_1_fold_2.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 3  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 4  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# Number of rows: 269
# Contents of temp_val_trial_1_fold_2.csv:
#                                               smiles  Activity2
# 0  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# 1  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# 2  CCOC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=...        1.0
# 3    C=CC(=O)Nc1ccc(S(=O)(=O)N2CCN(c3ncccc3C)CC2)cc1        1.0
# 4  COC(=O)C=CCCC(NC(=O)c1cncc(C(=O)O)c1)C(=O)NC(C...        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_1_fold_2.csv --dataset_type classification --save_dir acheckp/trial_1_fold_2 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_1_fold_2.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
# ...
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_2_fold_2',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 2 fold 2: Command '['chemprop_train', '--data_path', 'temp_train_trial_2_fold_2.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_2_fold_2', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 4/5...
# Contents of temp_train_trial_2_fold_3.csv:
#                                               smiles  Activity2
# 0  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 1  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 2  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 3  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# 4  O=C(CCl)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# Number of rows: 269
# Contents of temp_val_trial_2_fold_3.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# 2  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# 3  COC(=O)C=CCCC(NC(=O)c1cc([N+](=O)[O-])ccc1C(=O...        1.0
# 4        CCn1nc(-c2ccc(OC)cc2)nc2c(=O)n(C)c(=O)nc1-2        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_2_fold_3.csv --dataset_type classification --save_dir acheckp/trial_2_fold_3 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_2_fold_3.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_2_fold_3',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 2 fold 3: Command '['chemprop_train', '--data_path', 'temp_train_trial_2_fold_3.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_2_fold_3', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
#   Starting fold 5/5...
# Contents of temp_train_trial_2_fold_4.csv:
#                                               smiles  Activity2
# 0  COC(=O)c1ccc(COC(=O)N2CCN(C(=O)CNC(=O)CBr)CC2)cc1        1.0
# 1  O=C(CBr)NCC(=O)N1CCN(C(=O)C23CC4CC(CC(C4)C2)C3...        1.0
# 2  C=CC(=O)NCC(=O)N1CCN(S(=O)(=O)c2cccc3c(N(C)C)c...        1.0
# 3  O=C(CBr)NCC(=O)N1CCN(C(=O)OCC23CC4CC(CC(C4)C2)...        1.0
# 4  COC(=O)c1ccc2cc(COC(=O)N3CCN(C(=O)CNC(=O)CCl)C...        1.0
# Number of rows: 269
# Contents of temp_val_trial_2_fold_4.csv:
#                                               smiles  Activity2
# 0  COC(=O)C=CCCC(NC(=O)c1ccc([N+](=O)[O-])cc1C(=O...        1.0
# 1  CCOC(=O)C=CCCC(NC(=O)OCc1ccccc1)C(=O)NC(CCC(N)...        1.0
# 2  COC(=O)C=CCCC(NC(=O)c1nccnc1C(=O)O)C(=O)NC(C(=...        1.0
# 3  COC(=O)C=CCCC(NC(=O)c1cc(Cl)c(Cl)cc1C(=O)O)C(=...        1.0
# 4  COC(=O)C=CCCC(NC(=O)c1cncc(C(=O)O)c1)C(=O)NC(C...        1.0
# Number of rows: 67
# Command line
# python /Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train --data_path temp_train_trial_2_fold_4.csv --dataset_type classification --save_dir acheckp/trial_2_fold_4 --target_columns Activity --epochs 30 --batch_size 50
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'temp_train_trial_2_fold_4.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'acheckp/trial_2_fold_4',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.8, 0.1, 0.1],
#  'split_type': 'random',
#  'target_columns': ['Activity'],
#  'target_weights': None,
#  'task_names': ['Activity'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/bin/chemprop_train", line 8, in <module>
#     sys.exit(chemprop_train())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 208, in chemprop_train
#     cross_validate(args=TrainArgs().parse_args(), train_func=run_training)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/utils.py", line 591, in wrap
#     result = func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/train/cross_validate.py", line 76, in cross_validate
#     data = get_data(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/chemprop/data/utils.py", line 473, in get_data
#     raise ValueError(f'Data file did not contain all provided target columns: {target_columns}. Data file field names are: {fieldnames}')
# ValueError: Data file did not contain all provided target columns: ['Activity']. Data file field names are: ['smiles', 'Activity2']
# Error during training or prediction for trial 2 fold 4: Command '['chemprop_train', '--data_path', 'temp_train_trial_2_fold_4.csv', '--dataset_type', 'classification', '--save_dir', 'acheckp/trial_2_fold_4', '--target_columns', 'Activity', '--epochs', '30', '--batch_size', '50']' returned non-zero exit status 1.
# Average metrics over 50 trials of 5-fold cross-validation:
# AUC: nan
# F1 Score: nan
# Accuracy: nan
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
import os
import numpy as np

def evaluate_predictions(predictions_path, test_path):
    # Load predictions and testing data
    preds_df = pd.read_csv(predictions_path)
    test_df = pd.read_csv(test_path)
    # preds_df["Activity2"] = preds_df["Activity"]
    # preds_df.drop(["Activity"], axis = 1)

    

    # Ensure the data has 'smiles' and 'preds' columns for predictions and 'smiles' and 'Activity' for testing
    if 'smiles' not in preds_df.columns or 'Activity2' not in preds_df.columns:
        raise ValueError("Prediction file must contain 'smiles' and 'Activity2' columns.")
    if 'smiles' not in test_df.columns or 'Activity' not in test_df.columns:
        raise ValueError("Testing file must contain 'smiles' and 'Activity' columns.")

    # Filter out rows with 'Invalid Smiles' in predictions
    preds_df = preds_df[preds_df['Activity2'] != 'Invalid Smiles']
    
    # Convert valid predictions to numeric
    preds_df['Activity2'] = pd.to_numeric(preds_df['Activity2'], errors='coerce')

    # Merge predictions with the testing data on 'smiles'
    merged_df = pd.merge(test_df, preds_df, on='smiles', how='inner')

    # Check if we have any valid data after merging
    if merged_df.empty:
        raise ValueError("No valid predictions found after merging.")

    # Extract true labels and predicted values
    true_labels = merged_df['Activity']
    preds = merged_df['Activity2'].astype(float)

    # Binarize predictions
    threshold = 0.5
    binary_preds = (preds > threshold).astype(int)

    # Calculate metrics
    print(true_labels)
    print(binary_preds)
    auc = roc_auc_score(true_labels, binary_preds)
    f1 = f1_score(true_labels, binary_preds)
    accuracy = accuracy_score(true_labels, binary_preds)

    return auc, f1, accuracy

def main():
    results = []

    # Loop through trials and folds
    num_trials = 3
    num_folds = 5

    for trial in range(num_trials):
        for fold in range(num_folds):
            pred_file = f'preds_trial_{trial}_fold_{fold}.csv'
            test_file = f'temp_val_trial_{trial}_fold_{fold}.csv'

            if os.path.exists(pred_file) and os.path.exists(test_file):
                print(f"Evaluating trial {trial}, fold {fold}...")

                auc, f1, accuracy = evaluate_predictions(pred_file, test_file)
                results.append({
                        'trial': trial,
                        'fold': fold,
                        'AUC': auc,
                        'F1': f1,
                        'Accuracy': accuracy
                })
    
    # Convert results to DataFrame
    results_df = pd.DataFrame(results)

    # Calculate average metrics
    avg_results = results_df.groupby(['trial']).mean().reset_index()
    avg_results.to_csv('average_metrics.csv', index=False)

    print("Evaluation complete. Results saved to 'average_metrics.csv'.")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 85
#      82     print("Evaluation complete. Results saved to 'average_metrics.csv'.")
#      84 if __name__ == "__main__":
# ---> 85     main()
#
# Cell In[2], line 79, in main()
#      76 results_df = pd.DataFrame(results)
#      78 # Calculate average metrics
# ---> 79 avg_results = results_df.groupby(['trial']).mean().reset_index()
#      80 avg_results.to_csv('average_metrics.csv', index=False)
#      82 print("Evaluation complete. Results saved to 'average_metrics.csv'.")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:8262, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8259     raise TypeError("You have to supply one of 'by' and 'level'")
#    8260 axis = self._get_axis_number(axis)
# -> 8262 return DataFrameGroupBy(
#    8263     obj=self,
#    8264     keys=by,
#    8265     axis=axis,
#    8266     level=level,
#    8267     as_index=as_index,
#    8268     sort=sort,
#    8269     group_keys=group_keys,
#    8270     observed=observed,
#    8271     dropna=dropna,
#    8272 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'trial'
